# %% [markdown]
# <a href="https://colab.research.google.com/github/nssliu/user/blob/master/tdxj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 创建一个数据集，二维，x作为宽度，y作为重量
# 数据集个数一共3个
# 数据的第一个特征为数据的第一个元素
Xt = [1,5,7]
Yt = [10,40,80]

Xt
# Out:
# [1, 5, 7]

# %%
import numpy as np

# %%
X = np.array(Xt)
X
Y = np.array(Yt)
Y
# Out:
# array([10, 40, 80])

# %%
# 绘制
import matplotlib.pyplot as plt

# x和y的数据
x = X
y = Y

# 创建图形和坐标轴
plt.figure()

# 在坐标轴上绘制x和y的数据点
plt.scatter(x, y, color='blue')  # 指定颜色为蓝色

# 设置标题和轴标签
plt.title('shilisandian')
plt.xlabel('x')
plt.ylabel('y')

# 显示图形
plt.show()

# %%
#y = wx +b

# %%
# (ypre_e - y_e)**2

# %%
# 原函数y_e的值
y_e = np.sum(Yt)
y_e
# Out:
# 130

# %%
# 通过w,b的变化求预测值的结果
def y_e_fun(w,b=0):
  y_pre_e = 0
  for xi in Xt:
    y_pre_e+=(w*xi+b)
  return y_pre_e
y_e_fun(2,0)
# Out:
# 26

# %%
# 损失函数：其实为距离的平方， (y_pre - y)**2 为假设的损失函数，因为一般都是从远到近再到远的
# wx的预测函数的值的和-实际的值的平方
# (y-w*x)**2 其中x，y均为常数，求导后的复合幂函数求导后为-2x(y-w*x) 结果为某w的斜率
# 由于(y-w*x)**2 和 (w*x-y)**2相同，我们求导为 2x(w*x-y)

# %%
#下一步步长
def get_w_step(g,rate):
  return g*rate

#求导数值
def d_fun(w):
  return

# %%
def w_d(X,Y,w):
  # 对导函数进行带入判断,
  w_gradient = 2*X*(w*X-Y)
  # 我们对斜率求平均值
  w_g_avg = np.sum(w_gradient) / np.size(Y)
  return w_g_avg

w_d(X,Y,w)
# Out:
# -463.3333333333333

# %%
# # 获取斜率
# w_d_t = w_d(X,Y,w)
# print(w_d_t)
# # 获取w走的步长
# step = get_w_step(w_d_t,rate)
# print(step)
# # 获取下一个w
# w = w-step
# print(w)
# Out:
# -463.3333333333333
# -139.0
# 140.0

# %%
# 学习率过大，导致收敛不到要求的范围
# end_w_d = 0.2
# w =1 # 初始值
# b= 0
# rate = 0.3 # 学习率
# while True:
#   # 获取斜率
#   w_d_t = w_d(X,Y,w)
#   print(w_d_t)
#   # 获取w走的步长
#   step = get_w_step(w_d_t,rate)
#   print(step)
#   # 获取下一个w
#   w = w-step
#   print(w)
#   if w_d_t <end_w_d and w_d_t > -0.2:
#     break

# print(w)
# Out:
# -463.3333333333333
# -139.0
# 140.0
# 6486.666666666667
# 1946.0
# -1806.0
# -90813.33333333333
# -27243.999999999996
# 25437.999999999996
# 1271386.6666666663
# 381415.9999999999
# -355977.9999999999
# -17799413.33333333
# -5339823.999999998
# 4983845.999999998
# 249191786.6666666
# 74757535.99999997
# -69773689.99999997
# -3488685013.333332
# -1046605503.9999995
# 976831813.9999995
# 48841590186.66665
# 14652477055.999994
# -13675645241.999994
# -683782262613.333
# -205134678783.9999
# 191459033541.9999
# 9572951676586.662
# 2871885502975.9985
# -2680426469433.9985
# -134021323472213.25
# -40206397041663.98
# 37525970572229.98
# 1876298528610985.8
# 562889558583295.7
# -525363588011065.7
# -2.6268179400553796e+16
# -7880453820166139.0
# 7355090232155073.0
# 3.6775451160775315e+17
# 1.1032635348232594e+17
# -1.0297126325017086e+17
# -5.148563162508544e+18
# -1.5445689487525632e+18
# 1.4415976855023923e+18
# 7.207988427511962e+19
# 2.1623965282535887e+19
# -2.0182367597033497e+19
# ...

# %%
end_w_d = 0.2
w =1 # 初始值
b= 0
rate = 0.01 # 学习率
while True:
  # 获取斜率
  w_d_t = w_d(X,Y,w)
  print(w_d_t)
  # 获取w走的步长
  step = get_w_step(w_d_t,rate)
  print(step)
  # 获取下一个w
  w = w-step
  print(w)
  if w_d_t <end_w_d and w_d_t > -0.2:
    break

print(w)
# Out:
# -463.3333333333333
# -4.633333333333333
# 5.633333333333333
# -231.6666666666667
# -2.3166666666666673
# 7.95
# -115.83333333333336
# -1.1583333333333337
# 9.108333333333334
# -57.91666666666662
# -0.5791666666666663
# 9.6875
# -28.958333333333332
# -0.2895833333333333
# 9.977083333333333
# -14.479166666666657
# -0.14479166666666657
# 10.121875
# -7.239583333333371
# -0.07239583333333371
# 10.194270833333333
# -3.619791666666709
# -0.03619791666666709
# 10.23046875
# -1.8098958333333333
# -0.01809895833333333
# 10.248567708333333
# -0.9049479166666572
# -0.009049479166666572
# 10.2576171875
# -0.45247395833337123
# -0.004524739583333713
# 10.262141927083333
# -0.2262369791667093
# -0.0022623697916670927
# 10.264404296875
# -0.11311848958333333
# -0.0011311848958333332
# 10.265535481770833
# 10.265535481770833

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设定斜率和截距
m = 10.265535481770833  # 斜率
b = 0.0  # 截距

# 创建一个x值的范围
x = np.linspace(-10, 10, 200)

# 根据直线方程计算对应的y值
y = m * x + b

# 创建图形和坐标轴
plt.figure()

# 在坐标轴上绘制直线
plt.plot(x, y, label='y = {}x + {}'.format(m, b))

# 设置标题和轴标签
plt.title('根据斜率和截距绘制的直线')
plt.xlabel('x轴')
plt.ylabel('y轴')

# 显示图例
plt.legend()

# 显示图形
plt.show()
